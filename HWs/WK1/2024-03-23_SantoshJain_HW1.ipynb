def loss(x,y,m,b):
   y_predicted = model(x,m,b)
   return np.power( y - y_predicted, 2 )

# %%
def updated_m(x,y,m,b,learning_rate):
   dL_dm = - 2 * x * (y - model(x,m,b))
   dL_dm = np.mean(dL_dm)
   return m - learning_rate * dL_dm

def updated_b(x,y,m,b,learning_rate):
   dL_db = - 2 * (y - model(x,m,b))
   dL_db = np.mean(dL_db)
   return b - learning_rate * dL_db

m = 5.
b = 1000.
print('y_i = %.2f * x + %.2f' % (m,b))

l = loss(x,y,m,b)
print('first 10 loss values: ',l[:10])

learning_rate = 1e-9
m = updated_m(x,y,m,b,learning_rate)
b = updated_b(x,y,m,b,learning_rate)
print('y_i = %.2f * x + %.2f     previously calculated: y_i = %.2f * x + %.2f' % (m,b,m_calc,b_calc))
plot_data(x,y,m,b)
# Out:
# y_i = 5.00 * x + 1000.00
# first 10 loss values:  [3.03421561e+10 3.55511025e+10 1.24579082e+10 1.91656336e+10
#  1.60604929e+10 2.04432804e+10 1.72410030e+10 1.76517796e+10
#  1.52769600e+10 2.18152900e+10]
# y_i = 5.47 * x + 1000.00     previously calculated: y_i = 87.69 * x + 34754.08

# %%
# set our initial slope and intercept
m = 5.
b = 1000.
# batch_size = 60
# set a learning rate for each parameter
learning_rate_m = 1e-7
learning_rate_b = 1e-1
# use these to plot our progress over time
loss_history = []

batch_size = 32
# we run our loop N times

loop_N = 30*len(data) // batch_size
for i in range(loop_N):
   
   # convert panda data to numpy arrays, one for the "Ground Living Area" and one for "Sale Price"
   data_batch = data.sample(batch_size)
   data_x = data_batch['GrLivArea'].to_numpy()
   data_y = data_batch['SalePrice'].to_numpy()
   
   # update our slope and intercept based on the current values
   m = updated_m(data_x,data_y,m,b,learning_rate_m)
   b = updated_b(data_x,data_y,m,b,learning_rate_b)

   # calculate the loss value
   loss_value = np.mean(loss(data_x,data_y,m,b))

   # keep a history of our loss values
   loss_history.append(loss_value)

   # print our progress
   print('[%03d]  dy_i = %.2f * x + %.2f     previously calculated: y_i = %.2f * x + %.2f    loss: %f' % (i,m,b,m_calc,b_calc,loss_value))
   
   # close/delete previous plots
   plt.close('all')
   
   # create a 1 by 2 plot grid
   fig,ax = plt.subplots(1,2,figsize=(18,6),dpi=80)
   # lot our usual output
   plot_data(data_x,data_y,m,b,ax[0])

   # here we also plot the calculated linear fit for comparison
   line_x = np.arange(data_x.min(),data_x.max())
   line_y = line_x * m_calc + b_calc
   ax[0].plot(line_x,line_y,'b-',label='calculated')
   # add a legend to the plot and x/y labels
   ax[0].legend()
   ax[0].set_xlabel('square footage')
   ax[0].set_ylabel('sale price')

   # plot the loss 
   loss_x = np.arange(0,len(loss_history))
   loss_y = np.asarray(loss_history)
   ax[1].plot(loss_x,loss_y)
   ax[1].set_yscale('log')
   ax[1].set_xlabel('loop step')
   ax[1].set_ylabel('loss')
   plt.show()
   # gives us time to see the plot
   time.sleep(2.5)
   # clears the plot when the next plot is ready to show.
   ipydis.clear_output(wait=True)
# Out:
# [515]  dy_i = 93.47 * x + 29030.76     previously calculated: y_i = 87.69 * x + 34754.08    loss: 948815353.407922

# %%
# set our initial slope and intercept
m = 5.
b = 1000.
# batch_size = 60
# set a learning rate for each parameter
learning_rate_m = 1e-7
learning_rate_b = 1e-1
# use these to plot our progress over time
loss_history = []

batch_size = 64
# we run our loop N times

loop_N = 30*len(data) // batch_size
print ('loop step is equal to', loop_N)
for i in range(loop_N):
   
   # convert panda data to numpy arrays, one for the "Ground Living Area" and one for "Sale Price"
   data_batch = data.sample(batch_size)
   data_x = data_batch['GrLivArea'].to_numpy()
   data_y = data_batch['SalePrice'].to_numpy()
   
   # update our slope and intercept based on the current values
   m = updated_m(data_x,data_y,m,b,learning_rate_m)
   b = updated_b(data_x,data_y,m,b,learning_rate_b)

   # calculate the loss value
   loss_value = np.mean(loss(data_x,data_y,m,b))

   # keep a history of our loss values
   loss_history.append(loss_value)

   # print our progress
   print('[%03d]  dy_i = %.2f * x + %.2f     previously calculated: y_i = %.2f * x + %.2f    loss: %f' % (i,m,b,m_calc,b_calc,loss_value))
   
   # close/delete previous plots
   plt.close('all')
   
   # create a 1 by 2 plot grid
   fig,ax = plt.subplots(1,2,figsize=(18,6),dpi=80)
   # lot our usual output
   plot_data(data_x,data_y,m,b,ax[0])

   # here we also plot the calculated linear fit for comparison
   line_x = np.arange(data_x.min(),data_x.max())
   line_y = line_x * m_calc + b_calc
   ax[0].plot(line_x,line_y,'b-',label='calculated')
   # add a legend to the plot and x/y labels
   ax[0].legend()
   ax[0].set_xlabel('square footage')
   ax[0].set_ylabel('sale price')

   # plot the loss 
   loss_x = np.arange(0,len(loss_history))
   loss_y = np.asarray(loss_history)
   ax[1].plot(loss_x,loss_y)
   ax[1].set_yscale('log')
   ax[1].set_xlabel('loop step')
   ax[1].set_ylabel('loss')
   plt.show()
   # gives us time to see the plot
   time.sleep(2.5)
   # clears the plot when the next plot is ready to show.
   ipydis.clear_output(wait=True)
# Out:
# [075]  dy_i = 95.25 * x + 29917.10     previously calculated: y_i = 87.69 * x + 34754.08    loss: 3759911038.598185
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 40
#      37 plt.close('all')
#      39 # create a 1 by 2 plot grid
# ---> 40 fig,ax = plt.subplots(1,2,figsize=(18,6),dpi=80)
#      41 # lot our usual output
#      42 plot_data(data_x,data_y,m,b,ax[0])
#
# File /soft/datascience/conda/2023-10-04/mconda3/lib/python3.10/site-packages/matplotlib/pyplot.py:1599, in subplots(nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw, **fig_kw)
#    1455 """
#    1456 Create a figure and a set of subplots.
#    1457
#    (...)
#    1596
#    1597 """
#    1598 fig = figure(**fig_kw)
# -> 1599 axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1600                    squeeze=squeeze, subplot_kw=subplot_kw,
#    1601                    gridspec_kw=gridspec_kw, height_ratios=height_ratios,
#    1602                    width_ratios=width_ratios)
#    1603 return fig, axs
#
# File /soft/datascience/conda/2023-10-04/mconda3/lib/python3.10/site-packages/matplotlib/figure.py:931, in FigureBase.subplots(self, nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw)
#     928     gridspec_kw['width_ratios'] = width_ratios
#     930 gs = self.add_gridspec(nrows, ncols, figure=self, **gridspec_kw)
# --> 931 axs = gs.subplots(sharex=sharex, sharey=sharey, squeeze=squeeze,
#     932                   subplot_kw=subplot_kw)
#     933 return axs
#
# File /soft/datascience/conda/2023-10-04/mconda3/lib/python3.10/site-packages/matplotlib/gridspec.py:298, in GridSpecBase.subplots(self, sharex, sharey, squeeze, subplot_kw)
#     296         subplot_kw["sharex"] = shared_with[sharex]
#     297         subplot_kw["sharey"] = shared_with[sharey]
# --> 298         axarr[row, col] = figure.add_subplot(
#     299             self[row, col], **subplot_kw)
#     301 # turn off redundant tick labeling
#     302 if sharex in ["col", "all"]:
#
# File /soft/datascience/conda/2023-10-04/mconda3/lib/python3.10/site-packages/matplotlib/figure.py:782, in FigureBase.add_subplot(self, *args, **kwargs)
#     780         args = tuple(map(int, str(args[0])))
#     781     projection_class, pkw = self._process_projection_requirements(**kwargs)
# --> 782     ax = projection_class(self, *args, **pkw)
#     783     key = (projection_class, pkw)
#     784 return self._add_axes_internal(ax, key)
#
# File /soft/datascience/conda/2023-10-04/mconda3/lib/python3.10/site-packages/matplotlib/axes/_base.py:678, in _AxesBase.__init__(self, fig, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, *args, **kwargs)
#     675 self.set_axisbelow(mpl.rcParams['axes.axisbelow'])
#     677 self._rasterization_zorder = None
# --> 678 self.clear()
#     680 # funcs used to format x and y - fall back on major formatters
#     681 self.fmt_xdata = None
#
# File /soft/datascience/conda/2023-10-04/mconda3/lib/python3.10/site-packages/matplotlib/axes/_base.py:1388, in _AxesBase.clear(self)
#    1386     self.cla()
#    1387 else:
# -> 1388     self.__clear()
#
# File /soft/datascience/conda/2023-10-04/mconda3/lib/python3.10/site-packages/matplotlib/axes/_base.py:1355, in _AxesBase.__clear(self)
#    1351 self.patch.set_transform(self.transAxes)
#    1353 self.set_axis_on()
# -> 1355 self.xaxis.set_clip_path(self.patch)
#    1356 self.yaxis.set_clip_path(self.patch)
#    1358 if self._sharex is not None:
#
# File /soft/datascience/conda/2023-10-04/mconda3/lib/python3.10/site-packages/matplotlib/_api/deprecation.py:297, in rename_parameter.<locals>.wrapper(*args, **kwargs)
#     292     warn_deprecated(
#     293         since, message=f"The {old!r} parameter of {func.__name__}() "
#     294         f"has been renamed {new!r} since Matplotlib {since}; support "
#     295         f"for the old name will be dropped %(removal)s.")
#     296     kwargs[new] = kwargs.pop(old)
# --> 297 return func(*args, **kwargs)
#
# File /soft/datascience/conda/2023-10-04/mconda3/lib/python3.10/site-packages/matplotlib/axis.py:1111, in Axis.set_clip_path(self, path, transform)
#    1108 @_api.rename_parameter("3.8", "clippath", "path")
#    1109 def set_clip_path(self, path, transform=None):
#    1110     super().set_clip_path(path, transform)
# -> 1111     for child in self.majorTicks + self.minorTicks:
#    1112         child.set_clip_path(path, transform)
#    1113     self.stale = True
#
# File /soft/datascience/conda/2023-10-04/mconda3/lib/python3.10/site-packages/matplotlib/axis.py:591, in _LazyTickList.__get__(self, instance, owner)
#     589 else:
#     590     instance.minorTicks = []
# --> 591     tick = instance._get_tick(major=False)
#     592     instance.minorTicks.append(tick)
#     593     return instance.minorTicks
#
# File /soft/datascience/conda/2023-10-04/mconda3/lib/python3.10/site-packages/matplotlib/axis.py:1562, in Axis._get_tick(self, major)
#    1558     raise NotImplementedError(
#    1559         f"The Axis subclass {self.__class__.__name__} must define "
#    1560         "_tick_class or reimplement _get_tick()")
#    1561 tick_kw = self._major_tick_kw if major else self._minor_tick_kw
# -> 1562 return self._tick_class(self.axes, 0, major=major, **tick_kw)
#
# File /soft/datascience/conda/2023-10-04/mconda3/lib/python3.10/site-packages/matplotlib/axis.py:418, in XTick.__init__(self, *args, **kwargs)
#     415 ax = self.axes
#     416 self.tick1line.set(
#     417     data=([0], [0]), transform=ax.get_xaxis_transform("tick1"))
# --> 418 self.tick2line.set(
#     419     data=([0], [1]), transform=ax.get_xaxis_transform("tick2"))
#     420 self.gridline.set(
#     421     data=([0, 0], [0, 1]), transform=ax.get_xaxis_transform("grid"))
#     422 # the y loc is 3 points below the min of y axis
#
# File /soft/datascience/conda/2023-10-04/mconda3/lib/python3.10/site-packages/matplotlib/artist.py:147, in Artist.__init_subclass__.<locals>.<lambda>(self, **kwargs)
#     139 if not hasattr(cls.set, '_autogenerated_signature'):
#     140     # Don't overwrite cls.set if the subclass or one of its parents
#     141     # has defined a set method set itself.
#     142     # If there was no explicit definition, cls.set is inherited from
#     143     # the hierarchy of auto-generated set methods, which hold the
#     144     # flag _autogenerated_signature.
#     145     return
# --> 147 cls.set = lambda self, **kwargs: Artist.set(self, **kwargs)
#     148 cls.set.__name__ = "set"
#     149 cls.set.__qualname__ = f"{cls.__qualname__}.set"
#
# File /soft/datascience/conda/2023-10-04/mconda3/lib/python3.10/site-packages/matplotlib/artist.py:1227, in Artist.set(self, **kwargs)
#    1223 def set(self, **kwargs):
#    1224     # docstring and signature are auto-generated via
#    1225     # Artist._update_set_signature_and_docstring() at the end of the
#    1226     # module.
# -> 1227     return self._internal_update(cbook.normalize_kwargs(kwargs, self))
#
# File /soft/datascience/conda/2023-10-04/mconda3/lib/python3.10/site-packages/matplotlib/cbook.py:1783, in normalize_kwargs(kw, alias_mapping)
#    1778 elif (isinstance(alias_mapping, type) and issubclass(alias_mapping, Artist)
#    1779       or isinstance(alias_mapping, Artist)):
#    1780     alias_mapping = getattr(alias_mapping, "_alias_map", {})
#    1782 to_canonical = {alias: canonical
# -> 1783                 for canonical, alias_list in alias_mapping.items()
#    1784                 for alias in alias_list}
#    1785 canonical_to_seen = {}
#    1786 ret = {}  # output dictionary
#
# KeyboardInterrupt:

# %%
# set our initial slope and intercept
m = 5.
b = 1000.
# batch_size = 60
# set a learning rate for each parameter
learning_rate_m = 1e-7
learning_rate_b = 1e-1
# use these to plot our progress over time
loss_history = []

batch_size = 128
# we run our loop N times

loop_N = 30*len(data) // batch_size
print ('loop step is equal to', loop_N)
for i in range(loop_N):
   
   # convert panda data to numpy arrays, one for the "Ground Living Area" and one for "Sale Price"
   data_batch = data.sample(batch_size)
   data_x = data_batch['GrLivArea'].to_numpy()
   data_y = data_batch['SalePrice'].to_numpy()
   
   # update our slope and intercept based on the current values
   m = updated_m(data_x,data_y,m,b,learning_rate_m)
   b = updated_b(data_x,data_y,m,b,learning_rate_b)

   # calculate the loss value
   loss_value = np.mean(loss(data_x,data_y,m,b))

   # keep a history of our loss values
   loss_history.append(loss_value)

   # print our progress
   print('[%03d]  dy_i = %.2f * x + %.2f     previously calculated: y_i = %.2f * x + %.2f    loss: %f' % (i,m,b,m_calc,b_calc,loss_value))
   
   # close/delete previous plots
   plt.close('all')
   
   # create a 1 by 2 plot grid
   fig,ax = plt.subplots(1,2,figsize=(18,6),dpi=80)
   # lot our usual output
   plot_data(data_x,data_y,m,b,ax[0])

   # here we also plot the calculated linear fit for comparison
   line_x = np.arange(data_x.min(),data_x.max())
   line_y = line_x * m_calc + b_calc
   ax[0].plot(line_x,line_y,'b-',label='calculated')
   # add a legend to the plot and x/y labels
   ax[0].legend()
   ax[0].set_xlabel('square footage')
   ax[0].set_ylabel('sale price')

   # plot the loss 
   loss_x = np.arange(0,len(loss_history))
   loss_y = np.asarray(loss_history)
   ax[1].plot(loss_x,loss_y)
   ax[1].set_yscale('log')
   ax[1].set_xlabel('loop step')
   ax[1].set_ylabel('loss')
   plt.show()
   # gives us time to see the plot
   time.sleep(2.5)
   # clears the plot when the next plot is ready to show.
   ipydis.clear_output(wait=True)

# %%
# set our initial slope and intercept
m = 5.
b = 1000.
# batch_size = 60
# set a learning rate for each parameter
learning_rate_m = 1e-7
learning_rate_b = 1e-1
# use these to plot our progress over time
loss_history = []

batch_size = 512
# we run our loop N times

loop_N = 30*len(data) // batch_size
print ('loop step is equal to', loop_N)
for i in range(loop_N):
   
   # convert panda data to numpy arrays, one for the "Ground Living Area" and one for "Sale Price"
   data_batch = data.sample(batch_size)
   data_x = data_batch['GrLivArea'].to_numpy()
   data_y = data_batch['SalePrice'].to_numpy()
   
   # update our slope and intercept based on the current values
   m = updated_m(data_x,data_y,m,b,learning_rate_m)
   b = updated_b(data_x,data_y,m,b,learning_rate_b)

   # calculate the loss value
   loss_value = np.mean(loss(data_x,data_y,m,b))

   # keep a history of our loss values
   loss_history.append(loss_value)

   # print our progress
   print('[%03d]  dy_i = %.2f * x + %.2f     previously calculated: y_i = %.2f * x + %.2f    loss: %f' % (i,m,b,m_calc,b_calc,loss_value))
   
   # close/delete previous plots
   plt.close('all')
   
   # create a 1 by 2 plot grid
   fig,ax = plt.subplots(1,2,figsize=(18,6),dpi=80)
   # lot our usual output
   plot_data(data_x,data_y,m,b,ax[0])

   # here we also plot the calculated linear fit for comparison
   line_x = np.arange(data_x.min(),data_x.max())
   line_y = line_x * m_calc + b_calc
   ax[0].plot(line_x,line_y,'b-',label='calculated')
   # add a legend to the plot and x/y labels
   ax[0].legend()
   ax[0].set_xlabel('square footage')
   ax[0].set_ylabel('sale price')

   # plot the loss 
   loss_x = np.arange(0,len(loss_history))
   loss_y = np.asarray(loss_history)
   ax[1].plot(loss_x,loss_y)
   ax[1].set_yscale('log')
   ax[1].set_xlabel('loop step')
   ax[1].set_ylabel('loss')
   plt.show()
   # gives us time to see the plot
   time.sleep(2.5)
   # clears the plot when the next plot is ready to show.
   ipydis.clear_output(wait=True)

# %%
fig,ax=plt.subplots(1,1,figsize=(18,6),dpi=80)
colors=['blue','red','orange','green','black','purple']

for loss_history,batch_size in zip(loss_batch,batch_sizes):


  loss_x=np.arange(0,len(loss_history))
  loss_y=np.asarray(loss_history)
  ax.plot(loss_x,loss_y,'o-')
ax.set_ylabel('loss')
ax.set_xlabel('loop step')
ax.legend(batch_sizes)
#ax.set_yscale('log')

plt.show()
